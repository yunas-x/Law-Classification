# %%
from pandas import read_csv


df = read_csv("expdata2.csv", delimiter=";", encoding='Windows-1251', error_bad_lines=False, encoding_errors="ignore")

# %%
df = df[df["actkind"] == 'Закон']

# %%
df
# Out:
#      regnumber     regdate  \
# 1        81-ПК  07.06.2022
# 2       453-ПК  07.10.2019
# 3       389-ПК  06.11.2014
# 4       513-ПК  02.03.2020
# 6       223-ПК  23.04.2018
# ...        ...         ...
# 3055    665-ПК  29.06.2016
# 3058    700-ПК  09.09.2016
# 3059     41-ПК  29.12.2016
# 3060    194-ПК  07.03.2018
# 3061    366-ПК  04.04.2019
#
#                                                                                                                                                                        shortcontent  \
# 1     О внесении изменения в часть 3 статьи 4 Закона Пермского края "О финансовом обеспечении в связи с отдельными видами преобразования муниципальных образований в Пермском крае"
# 2                       О внесении изменений в Закон Пермского края "О финансовом обеспечении в связи с отдельными видами преобразования муниципальных образований в Пермском крае"
# ...

# %%
df[df.duplicated(['regnumber', 'formnamesed'])]
# Out:
#      regnumber regdate  \
# 859        NaN     NaN
# 960        NaN     NaN
# 961        NaN     NaN
# 962        NaN     NaN
# 1421       NaN     NaN
# 1833       NaN     NaN
# 2072       NaN     NaN
# 2217       NaN     NaN
# 2299       NaN     NaN
# 2486       NaN     NaN
# 2710       NaN     NaN
# 2721       NaN     NaN
#
#                                                                                                                                                                                                                                                    shortcontent  \
# 859                                                                                      Об утверждении Соглашения между Пермским краем и Кировской областью о сотрудничестве в торгово-экономической, научно-технической, социальной, культурной и иных сферах
# ...
